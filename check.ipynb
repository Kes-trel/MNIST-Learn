# %%
from TensorFlow_MNIST import df

# %%
df
# Out:
#    Epoch Time(s)      Loss  Accuracy %  Validation Loss  Validation Accuracy %
# 1       2.221505  0.425218   87.846297         0.208764              93.766665
# 2       1.341168  0.182419   94.696295         0.167236              95.116669
# 3       1.366395  0.140801   95.875925         0.147034              95.450002
# 4       1.415305  0.114137   96.683335         0.135508              95.800000
# 5       1.344002  0.095082   97.214812         0.134742              95.866668

# %%
import seaborn as sns

# %%
df
# Out:
#    Epoch Time(s)      Loss  Accuracy %  Validation Loss  Validation Accuracy %
# 1       2.221505  0.425218   87.846297         0.208764              93.766665
# 2       1.341168  0.182419   94.696295         0.167236              95.116669
# 3       1.366395  0.140801   95.875925         0.147034              95.450002
# 4       1.415305  0.114137   96.683335         0.135508              95.800000
# 5       1.344002  0.095082   97.214812         0.134742              95.866668

# %%
df1 = df.copy()
df1["Epoch"] = df1.index
df1
# Out:
#    Epoch Time(s)      Loss  ...  Validation Accuracy %  Epoch
# 1       2.221505  0.425218  ...              93.766665      1
# 2       1.341168  0.182419  ...              95.116669      2
# 3       1.366395  0.140801  ...              95.450002      3
# 4       1.415305  0.114137  ...              95.800000      4
# 5       1.344002  0.095082  ...              95.866668      5
#
# [5 rows x 6 columns]

# %%
data = df1[["Accuracy %","Validation Accuracy %"]]
data
# Out:
#    Accuracy %  Validation Accuracy %
# 1   87.846297              93.766665
# 2   94.696295              95.116669
# 3   95.875925              95.450002
# 4   96.683335              95.800000
# 5   97.214812              95.866668

# %%
sns.lineplot(data=data)
# Out:
# <AxesSubplot:>
