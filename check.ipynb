# %%
from TensorFlow_MNIST import df
# Out:
# 2021-06-10 16:27:32.563 WARNING root:
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run ipykernel_launcher [ARGUMENTS]
# 2021-06-10 16:27:32.565 INFO    absl: Load dataset info from C:\Users\kessi\tensorflow_datasets\mnist\3.0.1
# 2021-06-10 16:27:32.568 INFO    absl: Reusing dataset mnist (C:\Users\kessi\tensorflow_datasets\mnist\3.0.1)
# 2021-06-10 16:27:32.569 INFO    absl: Constructing tf.data.Dataset mnist for split None, from C:\Users\kessi\tensorflow_datasets\mnist\3.0.1
# Epoch 1/5
# 540/540 [==============================] - 2s 3ms/step - loss: 0.4323 - accuracy: 0.8758 - val_loss: 0.2244 - val_accuracy: 0.9362
# Epoch 2/5
# 540/540 [==============================] - 1s 3ms/step - loss: 0.1870 - accuracy: 0.9454 - val_loss: 0.1695 - val_accuracy: 0.9490
# Epoch 3/5
# 540/540 [==============================] - 1s 3ms/step - loss: 0.1384 - accuracy: 0.9584 - val_loss: 0.1467 - val_accuracy: 0.9565
# Epoch 4/5
# 540/540 [==============================] - 2s 3ms/step - loss: 0.1102 - accuracy: 0.9678 - val_loss: 0.1372 - val_accuracy: 0.9608
# Epoch 5/5
# 540/540 [==============================] - 2s 3ms/step - loss: 0.0918 - accuracy: 0.9729 - val_loss: 0.1304 - val_accuracy: 0.9622

# %%
df
# Out:
#    Epoch Time(s)      Loss  Accuracy %  Validation Loss  Validation Accuracy %
# 1       2.377720  0.432284   87.583333         0.224368              93.616664
# 2       1.464190  0.186985   94.535184         0.169489              94.900000
# 3       1.489349  0.138425   95.842594         0.146703              95.649999
# 4       1.576995  0.110151   96.777779         0.137158              96.083331
# 5       1.572642  0.091828   97.287035         0.130391              96.216667

# %%
import seaborn as sns

# %%
df
# Out:
#    Epoch Time(s)      Loss  Accuracy %  Validation Loss  Validation Accuracy %
# 1       2.377720  0.432284   87.583333         0.224368              93.616664
# 2       1.464190  0.186985   94.535184         0.169489              94.900000
# 3       1.489349  0.138425   95.842594         0.146703              95.649999
# 4       1.576995  0.110151   96.777779         0.137158              96.083331
# 5       1.572642  0.091828   97.287035         0.130391              96.216667

# %%
df1 = df.copy()
df1["Epoch"] = df1.index
df1
# Out:
#    Epoch Time(s)      Loss  Accuracy %  Validation Loss  \
# 1       2.377720  0.432284   87.583333         0.224368
# 2       1.464190  0.186985   94.535184         0.169489
# 3       1.489349  0.138425   95.842594         0.146703
# 4       1.576995  0.110151   96.777779         0.137158
# 5       1.572642  0.091828   97.287035         0.130391
#
#    Validation Accuracy %  Epoch
# 1              93.616664      1
# 2              94.900000      2
# 3              95.649999      3
# 4              96.083331      4
# 5              96.216667      5

# %%
data = df1[["Accuracy %","Validation Accuracy %"]]
data = df1[["Loss","Validation Loss"]]
data
# Out:
#        Loss  Validation Loss
# 1  0.432284         0.224368
# 2  0.186985         0.169489
# 3  0.138425         0.146703
# 4  0.110151         0.137158
# 5  0.091828         0.130391

# %%
sns.lineplot(data=data)
# Out:
# <AxesSubplot:>
