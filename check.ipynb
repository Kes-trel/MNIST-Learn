# %%
from TensorFlow_MNIST import df
# Out:
# 2021-06-11 07:51:56.141 WARNING root:
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run ipykernel_launcher [ARGUMENTS]
# 2021-06-11 07:51:56.143 INFO    absl: Load dataset info from C:\Users\kessi\tensorflow_datasets\mnist\3.0.1
# 2021-06-11 07:51:56.145 INFO    absl: Reusing dataset mnist (C:\Users\kessi\tensorflow_datasets\mnist\3.0.1)
# 2021-06-11 07:51:56.147 INFO    absl: Constructing tf.data.Dataset mnist for split None, from C:\Users\kessi\tensorflow_datasets\mnist\3.0.1
# Epoch 1/5
# 540/540 [==============================] - 2s 3ms/step - loss: 0.4015 - accuracy: 0.8861 - val_loss: 0.2138 - val_accuracy: 0.9345
# Epoch 2/5
# 540/540 [==============================] - 1s 3ms/step - loss: 0.1771 - accuracy: 0.9483 - val_loss: 0.1608 - val_accuracy: 0.9490
# Epoch 3/5
# 540/540 [==============================] - 1s 2ms/step - loss: 0.1322 - accuracy: 0.9607 - val_loss: 0.1375 - val_accuracy: 0.9585
# Epoch 4/5
# 540/540 [==============================] - 1s 2ms/step - loss: 0.1049 - accuracy: 0.9689 - val_loss: 0.1267 - val_accuracy: 0.9620
# Epoch 5/5
# 540/540 [==============================] - 1s 3ms/step - loss: 0.0878 - accuracy: 0.9740 - val_loss: 0.1202 - val_accuracy: 0.9645

# %%
df
# Out:
#    Epoch Time(s)      Loss  Accuracy %  Validation Loss  Validation Accuracy %
# 1       2.319716  0.401511   88.614815         0.213755              93.449998
# 2       1.412950  0.177148   94.833332         0.160762              94.900000
# 3       1.410649  0.132208   96.066666         0.137528              95.850003
# 4       1.403932  0.104909   96.894443         0.126670              96.200001
# 5       1.422590  0.087791   97.399998         0.120212              96.450001

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
df
# Out:
#    Epoch Time(s)      Loss  Accuracy %  Validation Loss  Validation Accuracy %
# 1       2.319716  0.401511   88.614815         0.213755              93.449998
# 2       1.412950  0.177148   94.833332         0.160762              94.900000
# 3       1.410649  0.132208   96.066666         0.137528              95.850003
# 4       1.403932  0.104909   96.894443         0.126670              96.200001
# 5       1.422590  0.087791   97.399998         0.120212              96.450001

# %%
df1 = df.copy()
df1["Epoch"] = df1.index
df1
# Out:
#    Epoch Time(s)      Loss  Accuracy %  Validation Loss  \
# 1       2.319716  0.401511   88.614815         0.213755
# 2       1.412950  0.177148   94.833332         0.160762
# 3       1.410649  0.132208   96.066666         0.137528
# 4       1.403932  0.104909   96.894443         0.126670
# 5       1.422590  0.087791   97.399998         0.120212
#
#    Validation Accuracy %  Epoch
# 1              93.449998      1
# 2              94.900000      2
# 3              95.850003      3
# 4              96.200001      4
# 5              96.450001      5

# %%
data = df1[["Accuracy %","Validation Accuracy %"]]
data = df1[["Loss","Validation Loss"]]
data
# Out:
#        Loss  Validation Loss
# 1  0.401511         0.213755
# 2  0.177148         0.160762
# 3  0.132208         0.137528
# 4  0.104909         0.126670
# 5  0.087791         0.120212

# %%
sns.lineplot(data=df[["Loss","Validation Loss"]]).xaxis.set_major_locator(ticker.MultipleLocator(1))

# %%
df11 = df1[["Accuracy %","Validation Accuracy %","Epoch"]]
df11 = df11.melt(id_vars="Epoch").rename(columns=str.title)
df11
# Out:
#    Epoch               Variable      Value
# 0      1             Accuracy %  88.614815
# 1      2             Accuracy %  94.833332
# 2      3             Accuracy %  96.066666
# 3      4             Accuracy %  96.894443
# 4      5             Accuracy %  97.399998
# 5      1  Validation Accuracy %  93.449998
# 6      2  Validation Accuracy %  94.900000
# 7      3  Validation Accuracy %  95.850003
# 8      4  Validation Accuracy %  96.200001
# 9      5  Validation Accuracy %  96.450001

# %%
min_y_axis = round(df11.min(axis=0)["Value"]-5,-1)
accuracy_barplot = sns.barplot(x="Epoch", y="Value", hue="Variable", data=df11).set(ylim=(min_y_axis, 100))
# Out:
# [(80.0, 100.0)]
